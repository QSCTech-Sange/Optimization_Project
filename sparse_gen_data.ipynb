# %%
from plot import *
from gen import *
from load_data import *  
from func_tools import *
from AGM import *
from GM import *
import warnings
warnings.filterwarnings('ignore')

# %%
centroids, points, N = gen_data(low=10,high=100) 
points[points>4]=0
plt.scatter(points[:,0],points[:,1])

# %%
points = sps.csr_matrix(points)

# %%
lbd = 0.05
delta = 1e-3
n = points.shape[0]
step = step_size(n,lbd,delta)
grad = lambda X,B,D: grad_hub_matrix(X,delta,points,lbd,B,D)

# %%
ans,AGM_loss = AGM(grad,points,step,0.001)

# %%
groups = get_group(ans,tol=0.00005)
plot_res_data(points,ans,groups,way='points')

# %%
points = np.array(points.todense())

# %%
ans,AGM_loss = AGM(grad,points,step,0.001)

# %%
groups = get_group(ans,tol=0.00005)
plot_res_data(points,ans,groups,way='points')
