# %% [markdown]
# # Weighted GM

# %%
from func_tools import *
from gen import *
from plot import *
from GM import *

# %% [markdown]
# ## 自测数据

# %%
centroids, points, N = gen_data()

# %%
lbd = 0.05
delta = 1e-3
func = lambda X,B,nw: loss_func_weighted(X,points,lbd,B,nw)
grad = lambda X,B,W: weight_grad(X,points,B,W,lbd)
ans2, GM_loss = GM_Weighted(points,func,grad,0.04,k=5,ctt=0.5)
groups = get_group(ans2,2)

# %%
plt.figure(figsize=(10,10))
plot_res_data(points,ans2,groups)
